# %%
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath('../src'))
from preprocessing import clean_data

# Paths
RAW_PATH = '../data/raw/marine_water.xlsm'
CLEAN_PATH = '../data/processed/water_quality_cleaned.csv'

# Load and clean
df_cleaned = clean_data(RAW_PATH)

# Save cleaned version
df_cleaned.to_csv(CLEAN_PATH, index=False)
df_cleaned.head()
# Out:
#            Depth Ammonia Nitrogen (mg/L)  Dissolved Oxygen (%saturation)  \
# 0  Surface Water                   0.053                             113
# 1   Middle Water                    0.04                              94
# 2   Bottom Water                   0.048                              94
# 3  Surface Water                   0.096                              85
# 4   Middle Water                   0.067                              93
#
#    Faecal Coliforms (cfu/100mL) Nitrate Nitrogen (mg/L)  \
# 0                           270                    0.12
# 1                           190                    0.11
# 2                           140                    0.11
# 3                           120                    0.04
# 4                           130                   0.029
#
#   Nitrite Nitrogen (mg/L) Orthophosphate Phosphorus (mg/L)  Temperature (°C)  \
# 0                   0.014                            0.018              19.5
# 1                    0.01                            0.017              19.5
# 2                    0.01                            0.018              19.5
# 3                   0.008                            0.017              19.4
# 4                   0.007                            0.013              19.4
#
#   Suspended Solids (mg/L)  Total Nitrogen (mg/L) Total Phosphorus (mg/L)  \
# 0                       3                   0.90                    0.07
# 1                     3.4                   0.80                    0.07
# 2                     3.4                   1.03                    0.07
# 3                     8.5                   0.79                    0.04
# 4                     2.4                   0.43                    0.03
#
#   Unionised Ammonia (mg/L) Volatile Suspended Solids (mg/L)  \
# 0                   <0.001                              0.6
# 1                    0.002                              0.6
# 2                    0.002                              0.6
# 3                    0.004                              1.8
# 4                    0.003                              0.5
#
#    Total Inorganic Nitrogen (mg/L) Total Kjeldahl Nitrogen (mg/L)  \
# 0                             0.19                           0.77
# 1                             0.16                           0.68
# 2                             0.17                           0.91
# 3                             0.14                           0.74
# 4                             0.10                           0.39
#
#   Chlorophyll-a (μg/L)  Dissolved Oxygen (mg/L)   pH
# 0                  0.6                      8.6  7.1
# 1                  0.5                      7.1  8.2
# 2                  0.4                      7.2  8.1
# 3                  1.8                      6.4  8.2
# 4                  2.4                      7.1  8.2
