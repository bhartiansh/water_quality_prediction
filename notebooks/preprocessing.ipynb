# %%
import pandas as pd
import sys
import os
import tensorflow as tf

sys.path.append(os.path.abspath('../src'))
from preprocessing import clean_data

# Paths
RAW_PATH = '../data/raw/marine_water_quality.xlsm'
CLEAN_PATH = '../data/processed/marine_water_quality_cleaned.csv'

with tf.device('/device:CPU:0'):
    # Load and clean
    df_cleaned = clean_data(RAW_PATH)


    # Save cleaned version
    df_cleaned.to_csv(CLEAN_PATH, index=False)
    df_cleaned.head()
# Out:
# 2025-04-22 13:53:59.730130: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2025-04-22 13:53:59.730162: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-04-22 13:53:59.730171: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2025-04-22 13:53:59.730381: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-04-22 13:53:59.730393: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
df_cleaned.head()
# Out:
#             Depth 5-day Biochemical Oxygen Demand (mg/L)  \
# 6   Surface Water                                    0.9
# 7    Middle Water                                    0.9
# 8    Bottom Water                                      1
# 12  Surface Water                                    1.3
# 13   Middle Water                                    0.9
#
#    Ammonia Nitrogen (mg/L) Chlorophyll-a (μg/L)  \
# 6                     0.15                  1.3
# 7                     0.13                  1.3
# 8                     0.16                  1.1
# 12                    0.26                    1
# 13                    0.23                  1.1
#
#     Dissolved Oxygen (%saturation)  Dissolved Oxygen (mg/L)  \
# 6                             80.0                      6.3
# 7                             78.0                      6.2
# 8                             82.0                      6.5
# 12                            58.0                      4.9
# ...
